# %%
from PIL import Image
import pandas as pd
import cv2
import os
import sys
from matplotlib.pyplot import imshow as ims
import pytesseract

# %%
img = cv2.imread("tesseract-python/1.png")

# %%
img2 = cv2.imread("tesseract-python/11.png")

# %%
ims(img2)

# %%
img2.shape
# Out:
# (1599, 1599, 3)

# %%
tamaño_columnas = int(img.shape[0]/2)

# %%
tamaño_final = int(img.shape[1]/2)

# %%
print(tamaño_columnas)
print(tamaño_final)
# Out:
# 641
# 1105

# %%
tamaño_final = img.shape[1]/4

# %%
cropped = img[0:tamaño_columnas*1, tamaño_final:tamaño_final*2]
partes_imagen.append(cropped)
ims(cropped)

# %%
#para cortar las imagenes
def crear_corte(imagen,col,row)
partes_imagen = []
tamaño_columnas = int(img.shape[0]/2)
tamaño_final = int(img.shape[1]/2)
col = 2
row = 2
for col in range(1,col+1):
    print(col)
    if col == 1:
        for row in range(row):
            cropped = img[0:tamaño_columnas*col, tamaño_final*(0+row):tamaño_final*(1+row)]
            partes_imagen.append(cropped)
    else:
        for row in range(row+1):
            print(row)
            cropped = img[tamaño_columnas:tamaño_columnas*col, tamaño_final*(0+row):tamaño_final*(1+row)]
            partes_imagen.append(cropped)
# Out:
# 1
# 2
# 0
# 1

# %%
cropped = img[tamaño_columnas:tamaño_columnas*(1+1), tamaño_final:tamaño_final*(2)]
ims(cropped)

# %%
len(partes_imagen)
# Out:
# 3

# %%
partes_imagen
# Out:
# [array([], shape=(0, 1105, 3), dtype=uint8),
#  array([], shape=(0, 1105, 3), dtype=uint8),
#  array([], shape=(0, 1105, 3), dtype=uint8)]

# %%
buenos.shape
# Out:
# (641, 1105, 3)

# %%
#para resicear las imagenes
r = 100/ img.shape[1]
dim = (100, int(img.shape[0]*r))

resized = cv2.resize(buenos, dim, interpolation = cv2.INTER_AREA)
print(resized.shape)
# Out:
# (58, 100, 3)

# %%
ims(resized)

# %%
buenos = partes_imagen[0]

# %%
cv2.imshow("gas",partes_imagen[5])
cv2.waitKey(0)
# Out:
# 255

# %%
print('Image Dimensions :', img.shape)
# Out:
# Image Dimensions : (1200, 1599, 3)

# %%
#gray = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

# %%
gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# %%
laiseca = gray[20:140,0:300]
ims(laiseca)

# %%
tratado = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

# %%
ims(layseca)

# %%
tratado2 = cv2.medianBlur(blackAndWhiteImage, 3)

# %%
ims(resized)

# %%
text = pytesseract.image_to_string(resized)
print(text)
# Out:
# BUENOS DIAS
#
# Que TAL ESTAS

# %%
#Conclusiones a tener en cuenta

# - Cuanto mas se afina el resize mejor funciona al reconocedor de texto.
